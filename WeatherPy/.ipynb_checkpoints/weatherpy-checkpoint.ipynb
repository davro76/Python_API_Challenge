# %%
# Dependencies ans Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as stats
from scipy.stats import linregress

# Import API key
from config import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create new empty list to hold the data
cities_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %%
# Performing API calls

print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# For each city name in cities list, do below things...
for index, city in enumerate(cities):
    try:
        response = requests.get(query_url + city).json()
        cities_name_list .append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter < 50:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 2 : georgetown
# City not found. Skipping...
# Processing Record 0 of Set 3 : sohag
# City not found. Skipping...
# Processing Record 0 of Set 4 : ushuaia
# Processing Record 0 of Set 5 : new norfolk
# Processing Record 0 of Set 6 : great falls
# Processing Record 0 of Set 7 : kawalu
# Processing Record 0 of Set 8 : vaini
# Processing Record 0 of Set 9 : bluff
# Processing Record 0 of Set 10 : tuatapere
# Processing Record 0 of Set 11 : qaanaaq
# Processing Record 0 of Set 12 : busselton
# Processing Record 0 of Set 13 : bhit shah
# Processing Record 0 of Set 14 : broome
# Processing Record 0 of Set 15 : chuy
# Processing Record 0 of Set 16 : belyy yar
# Processing Record 0 of Set 17 : rikitea
# Processing Record 0 of Set 18 : yining
# Processing Record 0 of Set 19 : mehamn
# Processing Record 0 of Set 20 : coquimbo
# City not found. Skipping...
# Processing Record 0 of Set 21 : tasiilaq
# Processing Record 0 of Set 22 : miyako
# Processing Record 0 of Set 23 : umm lajj
# City not found. Skipping...
# Processing Record 0 of Set 24 : hualmay
# Processing Record 0 of Set 25 : vostok
# Processing Record 0 of Set 26 : butaritari
# Processing Record 0 of Set 27 : mahebourg
# Processing Record 0 of Set 28 : geraldton
# Processing Record 0 of Set 29 : lebu
# Processing Record 0 of Set 30 : asau
# Processing Record 0 of Set 31 : hilo
# Processing Record 0 of Set 32 : san jose
# Processing Record 0 of Set 33 : avera
# Processing Record 0 of Set 34 : kapaa
# Processing Record 0 of Set 35 : ahipara
# Processing Record 0 of Set 36 : dordrecht
# Processing Record 0 of Set 37 : kavieng
# Processing Record 0 of Set 38 : saint-georges
# Processing Record 0 of Set 39 : montrose
# Processing Record 0 of Set 40 : mataura
# Processing Record 0 of Set 41 : baculin
# Processing Record 0 of Set 42 : cochrane
# Processing Record 0 of Set 43 : punta arenas
# Processing Record 0 of Set 44 : brindisi
# Processing Record 0 of Set 45 : yabelo
# Processing Record 0 of Set 46 : college
# Processing Record 0 of Set 47 : hovd
# Processing Record 0 of Set 48 : janauba
# Processing Record 0 of Set 49 : yellowknife
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 0 of Set 50 : anahuac
# Processing Record 0 of Set 51 : albany
# Processing Record 0 of Set 52 : barrow
# Processing Record 0 of Set 53 : redmond
# Processing Record 0 of Set 54 : bredasdorp
# Processing Record 0 of Set 55 : airai
# City not found. Skipping...
# Processing Record 0 of Set 56 : bonnyville
# Processing Record 0 of Set 57 : dourados
# Processing Record 0 of Set 58 : berlevag
# Processing Record 0 of Set 59 : husavik
# City not found. Skipping...
# Processing Record 0 of Set 60 : arraial do cabo
# Processing Record 0 of Set 61 : okhotsk
# City not found. Skipping...
# Processing Record 0 of Set 62 : port alfred
# Processing Record 0 of Set 63 : bengkulu
# Processing Record 0 of Set 64 : ewa beach
# Processing Record 0 of Set 65 : marsa matruh
# City not found. Skipping...
# Processing Record 0 of Set 66 : linxi
# Processing Record 0 of Set 67 : quatre cocos
# City not found. Skipping...
# Processing Record 0 of Set 68 : jamestown
# Processing Record 0 of Set 69 : torbay
# Processing Record 0 of Set 70 : saskylakh
# Processing Record 0 of Set 71 : victoria
# Processing Record 0 of Set 72 : clyde river
# Processing Record 0 of Set 73 : avarua
# Processing Record 0 of Set 74 : bowen
# Processing Record 0 of Set 75 : kodiak
# Processing Record 0 of Set 76 : morondava
# Processing Record 0 of Set 77 : lagoa
# Processing Record 0 of Set 78 : bahawalpur
# Processing Record 0 of Set 79 : epe
# Processing Record 0 of Set 80 : cape town
# Processing Record 0 of Set 81 : moroni
# Processing Record 0 of Set 82 : cravo norte
# Processing Record 0 of Set 83 : totness
# Processing Record 0 of Set 84 : alice springs
# Processing Record 0 of Set 85 : thompson
# Processing Record 0 of Set 86 : bekhtery
# Processing Record 0 of Set 87 : karymskoye
# Processing Record 0 of Set 88 : hobart
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 0 of Set 89 : norman wells
# Processing Record 0 of Set 90 : port elizabeth
# Processing Record 0 of Set 91 : sao joao da barra
# Processing Record 0 of Set 92 : ahuimanu
# Processing Record 0 of Set 93 : mar del plata
# Processing Record 0 of Set 94 : bressuire
# Processing Record 0 of Set 95 : port hedland
# Processing Record 0 of Set 96 : octeville
# Processing Record 0 of Set 97 : sadovoye
# Processing Record 0 of Set 98 : atuona
# Processing Record 0 of Set 99 : merbes-le-chateau
# Processing Record 0 of Set 100 : provideniya
# Processing Record 0 of Set 101 : sandakan
# Processing Record 0 of Set 102 : walvis bay
# Processing Record 0 of Set 103 : takoradi
# Processing Record 0 of Set 104 : cedar city
# Processing Record 0 of Set 105 : salalah
# Processing Record 0 of Set 106 : mandera
# Processing Record 0 of Set 107 : takhli
# Processing Record 0 of Set 108 : kaitangata
# Processing Record 0 of Set 109 : havelock
# Processing Record 0 of Set 110 : bandarbeyla
# Processing Record 0 of Set 111 : syracuse
# Processing Record 0 of Set 112 : waitati
# Processing Record 0 of Set 113 : copiapo
# Processing Record 0 of Set 114 : messina
# Processing Record 0 of Set 115 : mount gambier
# Processing Record 0 of Set 116 : marau
# Processing Record 0 of Set 117 : awbari
# Processing Record 0 of Set 118 : caravelas
# Processing Record 0 of Set 119 : flinders
# Processing Record 0 of Set 120 : matara
# Processing Record 0 of Set 121 : te anau
# Processing Record 0 of Set 122 : tuktoyaktuk
# Processing Record 0 of Set 123 : castro
# Processing Record 0 of Set 124 : cidreira
# Processing Record 0 of Set 125 : temnikov
# Processing Record 0 of Set 126 : portsmouth
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 0 of Set 127 : burnie
# Processing Record 0 of Set 128 : boulsa
# Processing Record 0 of Set 129 : henties bay
# Processing Record 0 of Set 130 : wamba
# City not found. Skipping...
# Processing Record 0 of Set 131 : chokurdakh
# Processing Record 0 of Set 132 : hermanus
# Processing Record 0 of Set 133 : harboore
# Processing Record 0 of Set 134 : burhaniye
# Processing Record 0 of Set 135 : port lincoln
# Processing Record 0 of Set 136 : kathmandu
# Processing Record 0 of Set 137 : honiara
# Processing Record 0 of Set 138 : de aar
# Processing Record 0 of Set 139 : ashqelon
# Processing Record 0 of Set 140 : isangel
# City not found. Skipping...
# Processing Record 0 of Set 141 : sola
# Processing Record 0 of Set 142 : rawson
# Processing Record 0 of Set 143 : east london
# Processing Record 0 of Set 144 : morant bay
# City not found. Skipping...
# Processing Record 0 of Set 145 : toccoa
# Processing Record 0 of Set 146 : charlestown
# Processing Record 0 of Set 147 : sobolevo
# Processing Record 0 of Set 148 : khandyga
# Processing Record 0 of Set 149 : port macquarie
# Processing Record 0 of Set 150 : russell
# Processing Record 0 of Set 151 : muravlenko
# Processing Record 0 of Set 152 : cabo san lucas
# Processing Record 0 of Set 153 : mugan
# Processing Record 0 of Set 154 : kahului
# Processing Record 0 of Set 155 : upernavik
# Processing Record 0 of Set 156 : san patricio
# Processing Record 0 of Set 157 : izacic
# Processing Record 0 of Set 158 : berdigestyakh
# Processing Record 0 of Set 159 : eureka
# Processing Record 0 of Set 160 : severo-kurilsk
# Processing Record 0 of Set 161 : araouane
# Processing Record 0 of Set 162 : kavaratti
# Processing Record 0 of Set 163 : nikolskoye
# Processing Record 0 of Set 164 : atbasar
# Processing Record 0 of Set 165 : tiksi
# Processing Record 0 of Set 166 : tevaitoa
# Processing Record 0 of Set 167 : pevek
# Processing Record 0 of Set 168 : manokwari
# Processing Record 0 of Set 169 : saint-philippe
# Processing Record 0 of Set 170 : fernandina beach
# Processing Record 0 of Set 171 : melito di porto salvo
# Processing Record 0 of Set 172 : shahe
# Processing Record 0 of Set 173 : saldanha
# Processing Record 0 of Set 174 : corralillo
# Processing Record 0 of Set 175 : khatanga
# Processing Record 0 of Set 176 : sur
# Processing Record 0 of Set 177 : mogok
# Processing Record 0 of Set 178 : kruisfontein
# Processing Record 0 of Set 179 : arevshat
# Processing Record 0 of Set 180 : karratha
# Processing Record 0 of Set 181 : longyearbyen
# Processing Record 0 of Set 182 : puerto ayora
# Processing Record 0 of Set 183 : coihaique
# Processing Record 0 of Set 184 : lorengau
# Processing Record 0 of Set 185 : kankon
# Processing Record 0 of Set 186 : tawau
# Processing Record 0 of Set 187 : boma
# City not found. Skipping...
# Processing Record 0 of Set 188 : puebloviejo
# Processing Record 0 of Set 189 : ribeira grande
# Processing Record 0 of Set 190 : katsuura
# Processing Record 0 of Set 191 : nome
# Processing Record 0 of Set 192 : saint-leu
# Processing Record 0 of Set 193 : yumen
# Processing Record 0 of Set 194 : katangli
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 0 of Set 195 : cayenne
# Processing Record 0 of Set 196 : lichuan
# Processing Record 0 of Set 197 : novichikha
# Processing Record 0 of Set 198 : lasa
# Processing Record 0 of Set 199 : gouyave
# Processing Record 0 of Set 200 : ponta do sol
# Processing Record 0 of Set 201 : ono
# Processing Record 0 of Set 202 : rio gallegos
# Processing Record 0 of Set 203 : puerto carreno
# Processing Record 0 of Set 204 : pecos
# Processing Record 0 of Set 205 : atar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 0 of Set 206 : umba
# Processing Record 0 of Set 207 : hofn
# Processing Record 0 of Set 208 : san quintin
# Processing Record 0 of Set 209 : palmares do sul
# Processing Record 0 of Set 210 : novopskov
# Processing Record 0 of Set 211 : waipawa
# Processing Record 0 of Set 212 : nishihara
# Processing Record 0 of Set 213 : la rioja
# Processing Record 0 of Set 214 : robertson
# Processing Record 0 of Set 215 : along
# Processing Record 0 of Set 216 : guanica
# City not found. Skipping...
# Processing Record 0 of Set 217 : kurilsk
# Processing Record 0 of Set 218 : dikson
# Processing Record 0 of Set 219 : lanxi
# Processing Record 0 of Set 220 : pacific grove
# Processing Record 0 of Set 221 : kirakira
# Processing Record 0 of Set 222 : kamskoye ustye
# Processing Record 0 of Set 223 : saint-joseph
# Processing Record 0 of Set 224 : harper
# Processing Record 0 of Set 225 : hithadhoo
# Processing Record 0 of Set 226 : salamiyah
# Processing Record 0 of Set 227 : les escoumins
# Processing Record 0 of Set 228 : el dorado
# Processing Record 0 of Set 229 : kalikino
# Processing Record 0 of Set 230 : ilulissat
# Processing Record 0 of Set 231 : la rochelle
# Processing Record 0 of Set 232 : biak
# Processing Record 0 of Set 233 : esperance
# Processing Record 0 of Set 234 : san juan
# Processing Record 0 of Set 235 : mujiayingzi
# Processing Record 0 of Set 236 : bud
# Processing Record 0 of Set 237 : huangmei
# Processing Record 0 of Set 238 : domoni
# Processing Record 0 of Set 239 : kabalo
# Processing Record 0 of Set 240 : waingapu
# Processing Record 0 of Set 241 : yar-sale
# City not found. Skipping...
# Processing Record 0 of Set 242 : urussu
# Processing Record 0 of Set 243 : qaqortoq
# Processing Record 0 of Set 244 : progreso
# Processing Record 0 of Set 245 : pisco
# Processing Record 0 of Set 246 : desbiens
# Processing Record 0 of Set 247 : grindavik
# Processing Record 0 of Set 248 : crossville
# Processing Record 0 of Set 249 : sambava
# Processing Record 0 of Set 250 : constitucion
# Processing Record 0 of Set 251 : rafai
# Processing Record 0 of Set 252 : presidencia roque saenz pena
# Processing Record 0 of Set 253 : bonavista
# Processing Record 0 of Set 254 : sinop
# Processing Record 0 of Set 255 : dunedin
# Processing Record 0 of Set 256 : alofi
# Processing Record 0 of Set 257 : ustyuzhna
# Processing Record 0 of Set 258 : tabuk
# Processing Record 0 of Set 259 : cherskiy
# Processing Record 0 of Set 260 : lavrentiya
# Processing Record 0 of Set 261 : jalu
# Processing Record 0 of Set 262 : conway
# Processing Record 0 of Set 263 : ban tak
# Processing Record 0 of Set 264 : hanting
# Processing Record 0 of Set 265 : la ronge
# Processing Record 0 of Set 266 : kaa-khem
# City not found. Skipping...
# Processing Record 0 of Set 267 : tigil
# Processing Record 0 of Set 268 : kalmunai
# Processing Record 0 of Set 269 : praia
# Processing Record 0 of Set 270 : esmeraldas
# Processing Record 0 of Set 271 : goma
# Processing Record 0 of Set 272 : chernyshevskiy
# Processing Record 0 of Set 273 : bonfim
# Processing Record 0 of Set 274 : asyut
# Processing Record 0 of Set 275 : faanui
# City not found. Skipping...
# Processing Record 0 of Set 276 : gold coast
# Processing Record 0 of Set 277 : piet retief
# Processing Record 0 of Set 278 : fortuna
# Processing Record 0 of Set 279 : egvekinot
# Processing Record 0 of Set 280 : shenkursk
# Processing Record 0 of Set 281 : acarau
# Processing Record 0 of Set 282 : srivardhan
# Processing Record 0 of Set 283 : agadir
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 0 of Set 284 : itamaraca
# Processing Record 0 of Set 285 : vanavara
# Processing Record 0 of Set 286 : strelka
# Processing Record 0 of Set 287 : sistranda
# Processing Record 0 of Set 288 : juneau
# Processing Record 0 of Set 289 : port-cartier
# Processing Record 0 of Set 290 : saint george
# Processing Record 0 of Set 291 : tiznit
# Processing Record 0 of Set 292 : nanortalik
# Processing Record 0 of Set 293 : joensuu
# Processing Record 0 of Set 294 : touros
# Processing Record 0 of Set 295 : bethel
# Processing Record 0 of Set 296 : kilemary
# Processing Record 0 of Set 297 : tual
# Processing Record 0 of Set 298 : shebalino
# Processing Record 0 of Set 299 : kerema
# Processing Record 0 of Set 300 : deputatskiy
# Processing Record 0 of Set 301 : saint-francois
# Processing Record 0 of Set 302 : telchac
# Processing Record 0 of Set 303 : kozhevnikovo
# Processing Record 0 of Set 304 : talnakh
# Processing Record 0 of Set 305 : caernarfon
# Processing Record 0 of Set 306 : vestmannaeyjar
# Processing Record 0 of Set 307 : sabang
# Processing Record 0 of Set 308 : mana
# City not found. Skipping...
# Processing Record 0 of Set 309 : ponta delgada
# Processing Record 0 of Set 310 : camocim
# City not found. Skipping...
# Processing Record 0 of Set 311 : kasane
# Processing Record 0 of Set 312 : komsomolets
# Processing Record 0 of Set 313 : zavoronezhskoye
# Processing Record 0 of Set 314 : sarangani
# Processing Record 0 of Set 315 : nizhniy odes
# Processing Record 0 of Set 316 : sumbe
# Processing Record 0 of Set 317 : nouadhibou
# Processing Record 0 of Set 318 : klaksvik
# Processing Record 0 of Set 319 : alta gracia
# Processing Record 0 of Set 320 : palmer
# Processing Record 0 of Set 321 : neiafu
# Processing Record 0 of Set 322 : watsa
# Processing Record 0 of Set 323 : diphu
# Processing Record 0 of Set 324 : thinadhoo
# Processing Record 0 of Set 325 : codrington
# Processing Record 0 of Set 326 : panaba
# Processing Record 0 of Set 327 : wajir
# Processing Record 0 of Set 328 : lagos
# Processing Record 0 of Set 329 : lindsay
# Processing Record 0 of Set 330 : havoysund
# Processing Record 0 of Set 331 : road town
# Processing Record 0 of Set 332 : alekseyevsk
# Processing Record 0 of Set 333 : bathsheba
# Processing Record 0 of Set 334 : luderitz
# Processing Record 0 of Set 335 : cabinda
# Processing Record 0 of Set 336 : voi
# Processing Record 0 of Set 337 : nizhneangarsk
# Processing Record 0 of Set 338 : kamenz
# Processing Record 0 of Set 339 : natchez
# Processing Record 0 of Set 340 : wajid
# Processing Record 0 of Set 341 : pangnirtung
# Processing Record 0 of Set 342 : menongue
# Processing Record 0 of Set 343 : mwandiga
# City not found. Skipping...
# Processing Record 0 of Set 344 : high level
# Processing Record 0 of Set 345 : itzehoe
# City not found. Skipping...
# Processing Record 0 of Set 346 : puri
# Processing Record 0 of Set 347 : argir
# Processing Record 0 of Set 348 : balakhta
# Processing Record 0 of Set 349 : carnarvon
# Processing Record 0 of Set 350 : bonthe
# City not found. Skipping...
# Processing Record 0 of Set 351 : petrokamenskoye
# Processing Record 0 of Set 352 : pochutla
# Processing Record 0 of Set 353 : souillac
# Processing Record 0 of Set 354 : petropavlovsk-kamchatskiy
# Processing Record 0 of Set 355 : lompoc
# Processing Record 0 of Set 356 : atambua
# Processing Record 0 of Set 357 : nambucca heads
# Processing Record 0 of Set 358 : ambilobe
# Processing Record 0 of Set 359 : santa maria
# Processing Record 0 of Set 360 : port moresby
# Processing Record 0 of Set 361 : kelvington
# Processing Record 0 of Set 362 : hasaki
# Processing Record 0 of Set 363 : kalabo
# Processing Record 0 of Set 364 : iqaluit
# Processing Record 0 of Set 365 : sanpaul
# Processing Record 0 of Set 366 : polonnaruwa
# Processing Record 0 of Set 367 : sao filipe
# Processing Record 0 of Set 368 : yanam
# Processing Record 0 of Set 369 : corner brook
# Processing Record 0 of Set 370 : herat
# Processing Record 0 of Set 371 : tura
# Processing Record 0 of Set 372 : qandala
# Processing Record 0 of Set 373 : gornyak
# Processing Record 0 of Set 374 : marienburg
# Processing Record 0 of Set 375 : richards bay
# Processing Record 0 of Set 376 : bogatyr
# Processing Record 0 of Set 377 : altay
# Processing Record 0 of Set 378 : laguna
# Processing Record 0 of Set 379 : destin
# Processing Record 0 of Set 380 : puro
# City not found. Skipping...
# Processing Record 0 of Set 381 : vila
# Processing Record 0 of Set 382 : bagdarin
# Processing Record 0 of Set 383 : hay river
# Processing Record 0 of Set 384 : vad
# Processing Record 0 of Set 385 : grand gaube
# Processing Record 0 of Set 386 : morros
# Processing Record 0 of Set 387 : redlands
# Processing Record 0 of Set 388 : viedma
# Processing Record 0 of Set 389 : tiszanana
# Processing Record 0 of Set 390 : kulu
# City not found. Skipping...
# Processing Record 0 of Set 391 : scarborough
# Processing Record 0 of Set 392 : beringovskiy
# Processing Record 0 of Set 393 : zyryanka
# Processing Record 0 of Set 394 : barra do bugres
# Processing Record 0 of Set 395 : vitre
# Processing Record 0 of Set 396 : ibra
# Processing Record 0 of Set 397 : bilma
# City not found. Skipping...
# Processing Record 0 of Set 398 : cotonou
# Processing Record 0 of Set 399 : caxito
# City not found. Skipping...
# Processing Record 0 of Set 400 : ermioni
# Processing Record 0 of Set 401 : santa cruz
# Processing Record 0 of Set 402 : arvika
# Processing Record 0 of Set 403 : bontang
# Processing Record 0 of Set 404 : kaniama
# Processing Record 0 of Set 405 : edson
# Processing Record 0 of Set 406 : buraydah
# City not found. Skipping...
# Processing Record 0 of Set 407 : bosaso
# Processing Record 0 of Set 408 : sawtell
# Processing Record 0 of Set 409 : ayan
# Processing Record 0 of Set 410 : dingle
# Processing Record 0 of Set 411 : champerico
# Processing Record 0 of Set 412 : cururupu
# City not found. Skipping...
# Processing Record 0 of Set 413 : solnechnyy
# Processing Record 0 of Set 414 : jaitaran
# Processing Record 0 of Set 415 : bastia
# Processing Record 0 of Set 416 : honggang
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 0 of Set 417 : lokoja
# Processing Record 0 of Set 418 : talcahuano
# Processing Record 0 of Set 419 : sorland
# Processing Record 0 of Set 420 : sorong
# Processing Record 0 of Set 421 : borazjan
# Processing Record 0 of Set 422 : vanimo
# Processing Record 0 of Set 423 : bayeux
# Processing Record 0 of Set 424 : beni
# Processing Record 0 of Set 425 : ravar
# City not found. Skipping...
# Processing Record 0 of Set 426 : lichinga
# Processing Record 0 of Set 427 : wanning
# Processing Record 0 of Set 428 : rocha
# Processing Record 0 of Set 429 : mountain home
# Processing Record 0 of Set 430 : tera
# Processing Record 0 of Set 431 : black river
# Processing Record 0 of Set 432 : kitgum
# Processing Record 0 of Set 433 : bubaque
# Processing Record 0 of Set 434 : boca do acre
# Processing Record 0 of Set 435 : vertientes
# Processing Record 0 of Set 436 : paralimni
# Processing Record 0 of Set 437 : vila praia de ancora
# Processing Record 0 of Set 438 : north bend
# Processing Record 0 of Set 439 : mbandaka
# Processing Record 0 of Set 440 : pontarlier
# City not found. Skipping...
# Processing Record 0 of Set 441 : boueni
# Processing Record 0 of Set 442 : muros
# Processing Record 0 of Set 443 : swift current
# Processing Record 0 of Set 444 : narsaq
# Processing Record 0 of Set 445 : rapid valley
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 0 of Set 446 : muana
# Processing Record 0 of Set 447 : adrar
# Processing Record 0 of Set 448 : vardo
# Processing Record 0 of Set 449 : aljezur
# Processing Record 0 of Set 450 : aksu
# Processing Record 0 of Set 451 : namibe
# Processing Record 0 of Set 452 : tazovskiy
# Processing Record 0 of Set 453 : aklavik
# Processing Record 0 of Set 454 : guatire
# Processing Record 0 of Set 455 : semnan
# Processing Record 0 of Set 456 : olga
# City not found. Skipping...
# Processing Record 0 of Set 457 : port-gentil
# Processing Record 0 of Set 458 : key west
# Processing Record 0 of Set 459 : neftcala
# Processing Record 0 of Set 460 : carutapera
# City not found. Skipping...
# Processing Record 0 of Set 461 : omsukchan
# Processing Record 0 of Set 462 : aswan
# Processing Record 0 of Set 463 : ukiah
# Processing Record 0 of Set 464 : sao sebastiao
# Processing Record 0 of Set 465 : noumea
# Processing Record 0 of Set 466 : villa union
# Processing Record 0 of Set 467 : namatanai
# Processing Record 0 of Set 468 : alzamay
# Processing Record 0 of Set 469 : olinda
# Processing Record 0 of Set 470 : sena madureira
# Processing Record 0 of Set 471 : mae sai
# Processing Record 0 of Set 472 : nabire
# Processing Record 0 of Set 473 : cabedelo
# Processing Record 0 of Set 474 : bambous virieux
# Processing Record 0 of Set 475 : novoukrayinka
# Processing Record 0 of Set 476 : tochio
# Processing Record 0 of Set 477 : eyl
# Processing Record 0 of Set 478 : yulara
# City not found. Skipping...
# Processing Record 0 of Set 479 : naze
# City not found. Skipping...
# Processing Record 0 of Set 480 : goderich
# Processing Record 0 of Set 481 : luan
# Processing Record 0 of Set 482 : tomigusuku
# Processing Record 0 of Set 483 : san roque
# Processing Record 0 of Set 484 : zapolyarnyy
# City not found. Skipping...
# Processing Record 0 of Set 485 : san andres
# Processing Record 0 of Set 486 : krasnoselkup
# Processing Record 0 of Set 487 : ketchikan
# Processing Record 0 of Set 488 : jiazi
# Processing Record 0 of Set 489 : ternat
# Processing Record 0 of Set 490 : aitape
# Processing Record 0 of Set 491 : alta floresta
# Processing Record 0 of Set 492 : kuopio
# Processing Record 0 of Set 493 : saint-pierre
# Processing Record 0 of Set 494 : albury
# Processing Record 0 of Set 495 : cockburn town
# Processing Record 0 of Set 496 : verkhnevilyuysk
# Processing Record 0 of Set 497 : pimentel
# Processing Record 0 of Set 498 : wewak
# Processing Record 0 of Set 499 : ancud
# Processing Record 0 of Set 500 : mweka
# Processing Record 0 of Set 501 : guisa
# Processing Record 0 of Set 502 : roebourne
# Processing Record 0 of Set 503 : punta de bombon
# Processing Record 0 of Set 504 : praya
# Processing Record 0 of Set 505 : huilong
# Processing Record 0 of Set 506 : aluksne
# Processing Record 0 of Set 507 : doha
# Processing Record 0 of Set 508 : lawrenceburg
# City not found. Skipping...
# Processing Record 0 of Set 509 : severobaykalsk
# Processing Record 0 of Set 510 : gat
# Processing Record 0 of Set 511 : mount isa
# Processing Record 0 of Set 512 : gotsu
# Processing Record 0 of Set 513 : los llanos de aridane
# Processing Record 0 of Set 514 : tucuman
# City not found. Skipping...
# Processing Record 0 of Set 515 : bairiki
# Processing Record 0 of Set 516 : edinburg
# Processing Record 0 of Set 517 : guadalupe victoria
# Processing Record 0 of Set 518 : kidal
# Processing Record 0 of Set 519 : faya
# Processing Record 0 of Set 520 : helena
# Processing Record 0 of Set 521 : muzhi
# Processing Record 0 of Set 522 : nelson bay
# Processing Record 0 of Set 523 : padang
# Processing Record 0 of Set 524 : antofagasta
# Processing Record 0 of Set 525 : ca mau
# Processing Record 0 of Set 526 : coahuayana
# Processing Record 0 of Set 527 : tarrega
# Processing Record 0 of Set 528 : vao
# Processing Record 0 of Set 529 : luorong
# Processing Record 0 of Set 530 : nikki
# Processing Record 0 of Set 531 : batagay
# Processing Record 0 of Set 532 : mulege
# Processing Record 0 of Set 533 : bolgatanga
# Processing Record 0 of Set 534 : calabozo
# Processing Record 0 of Set 535 : antalaha
# Processing Record 0 of Set 536 : konstantinovka
# City not found. Skipping...
# Processing Record 0 of Set 537 : moose factory
# Processing Record 0 of Set 538 : waddan
# Processing Record 0 of Set 539 : singkang
# Processing Record 0 of Set 540 : sitka
# Processing Record 0 of Set 541 : ranong
# Processing Record 0 of Set 542 : quelimane
# Processing Record 0 of Set 543 : okha
# Processing Record 0 of Set 544 : shu
# Processing Record 0 of Set 545 : arauco
# Processing Record 0 of Set 546 : zhoucun
# City not found. Skipping...
# Processing Record 0 of Set 547 : kungurtug
# Processing Record 0 of Set 548 : vuktyl
# Processing Record 0 of Set 549 : pavelets
# Processing Record 0 of Set 550 : ambanja
# Processing Record 0 of Set 551 : seda
# Processing Record 0 of Set 552 : hirara
# Processing Record 0 of Set 553 : hanzhong
# Processing Record 0 of Set 554 : haimen
# Processing Record 0 of Set 555 : kupang
# Processing Record 0 of Set 556 : half moon bay
# Processing Record 0 of Set 557 : iskateley
# Processing Record 0 of Set 558 : pirayu
# Processing Record 0 of Set 559 : yerbogachen
# Processing Record 0 of Set 560 : kargil
# City not found. Skipping...
# Processing Record 0 of Set 561 : luanda
# Processing Record 0 of Set 562 : ibipeba
# Processing Record 0 of Set 563 : tautira
# Processing Record 0 of Set 564 : aborlan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a dictionary with the data retrieved
weather_data_dict = { 
                "City" : cities_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
}

# Convert raw data to dataFrame
weather_df = pd.DataFrame.from_dict(weather_data_dict, orient='index')

# Transpose rows and columns
weather_df = weather_df.transpose()

# Download retrieved data into a csv file named cities_output
weather_df.to_csv("/Users/rodneydavermann/Desktop/Python_api_Challenge/OutputData/cities_output.csv", index=False,header=True, encoding='utf-8')

# Reload the output data set to perform some analysis 
weather_df = pd.read_csv("/Users/rodneydavermann/Desktop/Python_api_Challenge/OutputData/cities_output.csv")

# %%
# Determine the number of rows and columns of the weather_df datasate 
weather_df.shape
# Out:
# (563, 9)

# %%
# weather_df.dtypes
weather_df.dtypes
# Out:
# City           object
# Cloudiness      int64
# Country        object
# Date            int64
# Humidity        int64
# Lat           float64
# Lng           float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %%
# Describing weather_df's variables 
weather_df.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  563.000000  5.630000e+02  563.000000  563.000000  563.000000
# mean    55.403197  1.623899e+09   69.717584   19.923245   18.473653
# std     39.561104  7.638816e+01   20.584696   32.986495   89.907337
# min      0.000000  1.623898e+09   10.000000  -54.800000 -179.166700
# 25%     10.500000  1.623899e+09   59.000000   -7.657250  -59.733350
# 50%     67.000000  1.623899e+09   75.000000   24.093400   24.350000
# 75%     96.000000  1.623899e+09   85.000000   48.058350   98.078800
# max    100.000000  1.623899e+09  100.000000   78.218600  179.316700
#
#          Max Temp  Wind Speed
# count  563.000000  563.000000
# mean    67.632469    7.934121
# std     14.566570    5.673312
# min     30.310000    0.000000
# 25%     57.290000    3.735000
# 50%     69.390000    6.460000
# 75%     79.140000   10.830000
# max    106.270000   33.380000

# %% [markdown]
# # First requirement

# %%
# Latitude vs. Temperature Plot
N = 563
x = weather_df["Lat"]
y = weather_df["Max Temp"]
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2  
plt.scatter(x, y,s=area, c=colors, alpha=0.5)
plt.grid()
plt.xlabel("Latitude (degree)")
plt.ylabel("Temperatures (F)")
plt.title("City Latitude vs. Max Temperature (04/01/20)")
plt.xlim(-60,80)
plt.ylim(0,122)
plt.savefig("/Users/rodneydavermann/Desktop/Python_api_Challenge/OutputData/LatitudeTemperature.png")
plt.show()
print("The highest temperatures are observed at latitudes between 20 and 40 degrees, with a culminant point at 40 degrees.")
# Out:
# The highest temperatures are observed at latitudes between 20 and 40 degrees, with a culminant point at 40 degrees.

# %%
# Latitude vs. Humidity Plot
N = 563
x = weather_df["Lat"]
y = weather_df["Humidity"]
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2  
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.grid()
plt.xlabel("Latitude (degree)")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (04/01/20)")
plt.xlim(-60,80)
plt.ylim(0,110)
plt.savefig("/Users/rodneydavermann/Desktop/Python_api_Challenge/OutputData/LatitudeHumidity.png")
plt.show()
print("The above plot analyzes the relationship between Humidity in percentage and Latitude in degree.")
# Out:
# The above plot analyzes the relationship between Humidity in percentage and Latitude in degree.

# %%
# Latitude vs. Cloudiness Plot
N = 563
x = weather_df["Lat"]
y = weather_df["Cloudiness"]
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2  
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.grid()
plt.xlabel("Latitude (degree)")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (04/01/20)")
plt.xlim(-60,80)
plt.ylim(-10,110)
plt.savefig("/Users/rodneydavermann/Desktop/Python_api_Challenge/OutputData/LatitudeCloudiness.png")
plt.show()
print("The above plot analyzes the relationship between Cloudiness in percentage and Latitude in degree.")
# Out:
# The above plot analyzes the relationship between Cloudiness in percentage and Latitude in degree.

# %%
# Latitude vs. Wind Speed Plot
N = 563
x = weather_df["Lat"]
y = weather_df["Wind Speed"]
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2  
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.grid()
plt.xlabel("Latitude (degree)")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed (04/01/20)")
plt.xlim(-60,80)
plt.ylim(0,30)
plt.savefig("/Users/rodneydavermann/Desktop/Python_api_Challenge/OutputData/LatitudeWindSpeed.png")
plt.show()
print("The above plot analyzes the relationship between Wind Speed in miles per hour and Latitude in degree.")
# Out:
# The above plot analyzes the relationship between Wind Speed in miles per hour and Latitude in degree.

# %% [markdown]
# # Second requirement: linear regression on each relationship

# %%
# Subset weather_df into two datasets based on Latitude values (Lat>=0 and Lat<0)

NorthernHemisphere = weather_df[weather_df["Lat"]>=0]

SouthernHemisphere = weather_df[weather_df["Lat"]<0]

print(NorthernHemisphere.shape)

print(SouthernHemisphere.shape)
# Out:
# (389, 9)
# (174, 9)

# %% [markdown]
# # Northern Hemisphere Latitude and Temperature Scatterplot

# %%
# Create two arrays that represent Latitude and Temperature
x = NorthernHemisphere["Lat"]
y = NorthernHemisphere["Max Temp"]

# Define a model to calculate some important indicators
slope, intercept, r, p, std_err  = stats.linregress(x, y)

# define the regression function
def regression(x):
  return slope * x + intercept

linear_regression = list(map(regression, x))

# Size of the NorthernHemisphere dataset
N = 389

# Defining area and color for each point in the scatterplot
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2 

 # Scatterplot
plt.scatter(x, y,s=area, c=colors, alpha=0.5)

# x-axis title
plt.xlabel("Latitude (degree)")

#y-axis title
plt.ylabel("Temperatures (F)")

# Graph title
plt.title("City Latitude vs. Max Temperature (04/01/20)")


# Drawing a customize line of regression  in the plot 
plt.plot(x, linear_regression, color="red")

# display r and the scatterplot 
print(f"The coefficient of correlation is:{r}")
plt.savefig("/Users/rodneydavermann/Desktop/Python_api_Challenge/OutputData/LatitudeTemperature_reg1.png")
plt.show()

# Explanation of r
print("The Latitude is strongly and negatively correlated to the Temperature in the Northern Hemisphere.")
# Out:
# The coefficient of correlation is:-0.7169003881733982
# The Latitude is strongly and negatively correlated to the Temperature in the Northern Hemisphere.

# %% [markdown]
# # Southern Hemisphere Latitude and Temperature Scatterplot

# %%
# Create two arrays that represent Latitude and Temperature
x = SouthernHemisphere["Lat"]
y = SouthernHemisphere["Max Temp"]

# Define a model to calculate some important indicators
slope, intercept, r, p, std_err  = stats.linregress(x, y)

# define the regression function
def regression(x):
  return slope * x + intercept

linear_regression = list(map(regression, x))

# Size of the NorthernHemisphere dataset
N = 174

# Defining area and color for each point in the scatterplot
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2 

 # Scatterplot
plt.scatter(x, y,s=area, c=colors, alpha=0.5)

# x-axis title
plt.xlabel("Latitude (degree)")

#y-axis title
plt.ylabel("Temperatures (F)")

# Graph title
plt.title("City Latitude vs. Max Temperature (04/01/20)")

# Drawing a customize line of regression  in the plot 
plt.plot(x, linear_regression, color="red")

# display r and the scatterplot 
print(f"The coefficient of correlation is:{r}")
plt.savefig("/Users/rodneydavermann/Desktop/Python_api_Challenge/OutputData/LatitudeTemperature_reg2.png")
plt.show()

# Explanation of r
print("The Latitude is strongly and posittively correlated to the Temperature in the Southern Hemisphere.")
# Out:
# The coefficient of correlation is:0.7920968756800614
# The Latitude is strongly and positively correlated to the Temperature in the Southern Hemisphere.

# %% [markdown]
# # Northern Hemisphere Humidity (%) vs. Latitude Linear Regression Scatterplot

# %%
# Create two arrays that represent Latitude and Humidity
x = NorthernHemisphere["Lat"]
y = NorthernHemisphere["Humidity"]

# Define a model to calculate some important indicators
slope, intercept, r, p, std_err  = stats.linregress(x, y)

# define the regression function
def regression(x):
  return slope * x + intercept

linear_regression = list(map(regression, x))

# Size of the NorthernHemisphere dataset
N = 389

# Defining area and color for each point in the scatterplot
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2 

 # Scatterplot
plt.scatter(x, y,s=area, c=colors, alpha=0.5)

# x-axis title
plt.xlabel("Latitude (degree)")

#y-axis title
plt.ylabel("Humidity (%)")

# Graph title
plt.title("City Latitude vs. Humidity (%) (04/01/20)")


# Drawing a customize line of regression  in the plot 
plt.plot(x, linear_regression, color="red")

# display r and the scatterplot 
print(f"The coefficient of correlation is:{r}")
plt.savefig("/Users/rodneydavermann/Desktop/Python_api_Challenge/OutputData/LatitudeHumidity_reg3.png")
plt.show()

# Explanation of r
print("The Latitude and Humidity are not linearly correlated in the Northern Hemisphere.")
# Out:
# The coefficient of correlation is:-0.07772310995050338
# The Latitude and Humidity are not linearly correlated in the Northern Hemisphere.

# %% [markdown]
# # Southern Hemisphere Humidity (%) vs. Latitude Linear Regression Scatterplot

# %%
# Create two arrays that represent Latitude and Humidity
x = SouthernHemisphere["Lat"]
y = SouthernHemisphere["Humidity"]

# Define a model to calculate some important indicators
slope, intercept, r, p, std_err  = stats.linregress(x, y)

# define the regression function
def regression(x):
  return slope * x + intercept

linear_regression = list(map(regression, x))

# Size of the NorthernHemisphere dataset
N = 174

# Defining area and color for each point in the scatterplot
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2 

 # Scatterplot
plt.scatter(x, y,s=area, c=colors, alpha=0.5)

# x-axis title
plt.xlabel("Latitude (degree)")

#y-axis title
plt.ylabel("Humidity (%)")

# Drawing a customize line of regression  in the plot 
plt.plot(x, linear_regression, color="red")

# display r and the scatterplot 
print(f"The coefficient of correlation is:{r}")
plt.savefig("/Users/rodneydavermann/Desktop/Python_api_Challenge/OutputData/LatitudeHumidity_reg4.png")
plt.show()
# Out:
# The coefficient of correlation is:0.004439413093263263

# %% [markdown]
# # # Northern Hemisphere Cloudiness (%) vs. Latitude Linear Regression Scatterplot
